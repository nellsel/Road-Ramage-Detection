# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nellsel/yolor.git
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 500, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 500 (delta 2), reused 4 (delta 1), pack-reused 489
# Receiving objects: 100% (500/500), 3.44 MiB | 2.54 MiB/s, done.
# Resolving deltas: 100% (227/227), done.

# %%
# %cd yolor
# Out:
# /content/yolor

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 596 kB 31.4 MB/s
#      |████████████████████████████████| 776.7 MB 3.9 kB/s
#      |████████████████████████████████| 12.7 MB 77.0 MB/s
#      |████████████████████████████████| 1.5 MB 82.6 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/merged_road_damage_dataset.tar.gz ./

# %%
# !tar -xzf merged_road_damage_dataset.tar.gz

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv4/yolov4-csp.cfg ./

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv4/yolov4-csp.pth ./

# %%
# !python train.py --img 640 --data merged_dataset/data.yaml --cfg cfg/yolov4_csp.cfg --weights yolov4-csp.pth --device 0 --epochs 70 --cache --name merged_dataset_yolov4_csp_pretrained_noaug
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=True, cfg='cfg/yolov4_csp.cfg', data='merged_dataset/data.yaml', device='0', epochs=70, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='merged_dataset_yolov4_csp_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/merged_dataset_yolov4_csp_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolov4-csp.pth', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 8 threads.
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
# function calling for creating tar.gz file
make_tarfile('merged_dataset_yolov4_csp_pretrained_noaug.tar.gz', '/content/yolor/runs/train/merged_dataset_yolov4_csp_pretrained_noaug')

# %%
# %cp -r merged_dataset_yolov4_csp_pretrained_noaug.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOR/

# %%
# %cd /
# Out:
# /

# %%
# %cp -r  /content/drive/MyDrive/College/Thesis/RDD/YOLOR/merged_dataset_yolov4_csp_pretrained_noaug.tar.gz ./

# %%
# !tar -xzf merged_dataset_yolov4_csp_pretrained_noaug.tar.gz

# %%
# %cd content/yolor
# Out:
# /content/yolor

# %%
# !python train.py --img 640 --data merged_dataset/data.yaml --cfg cfg/yolov4_csp.cfg --weights runs/train/merged_dataset_yolov4_csp_pretrained_noaug/weights/last.pt --device 0 --epochs 100 --cache --name merged_dataset_yolov4_csp_pretrained_noaug  --exist-ok
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla T4, 15109MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=True, cfg='cfg/yolov4_csp.cfg', data='merged_dataset/data.yaml', device='0', epochs=100, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='merged_dataset_yolov4_csp_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/merged_dataset_yolov4_csp_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=8, weights='runs/train/merged_dataset_yolov4_csp_pretrained_noaug/weights/last.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 8 threads.
# ...

# %%
# function calling for creating tar.gz file
make_tarfile('merged_dataset_yolov4_csp_pretrained_noaug.tar.gz', 'runs/train/merged_dataset_yolov4_csp_pretrained_noaug')

# %%
# %cp -r merged_dataset_yolov4_csp_pretrained_noaugv2.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOR/
