# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/WongKinYiu/yolor.git
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 492, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 492 (delta 0), reused 0 (delta 0), pack-reused 489
# Receiving objects: 100% (492/492), 3.43 MiB | 13.76 MiB/s, done.
# Resolving deltas: 100% (225/225), done.

# %%
# %cd yolor
# Out:
# /content/yolor

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 596 kB 12.5 MB/s
#      |████████████████████████████████| 776.7 MB 3.9 kB/s
#      |████████████████████████████████| 12.7 MB 33.3 MB/s
#      |████████████████████████████████| 1.5 MB 51.0 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/RDD2020_yolo_aug_datav2.tar.gz ./

# %%
# !tar -xzvf RDD2020_yolo_aug_datav2.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# aug_data/labels/train/preset_2_Japan_012841_augmented.txt
# aug_data/labels/train/preset_2_Japan_012849_augmented.txt
# aug_data/labels/train/preset_2_Japan_012850_augmented.txt
# aug_data/labels/train/preset_2_Japan_012851_augmented.txt
# aug_data/labels/train/preset_2_Japan_012853_augmented.txt
# aug_data/labels/train/preset_2_Japan_012854_augmented.txt
# aug_data/labels/train/preset_2_Japan_012855_augmented.txt
# aug_data/labels/train/preset_2_Japan_012859_augmented.txt
# aug_data/labels/train/preset_2_Japan_012860_augmented.txt
# aug_data/labels/train/preset_2_Japan_012863_augmented.txt
# aug_data/labels/train/preset_2_Japan_012864_augmented.txt
# aug_data/labels/train/preset_2_Japan_012866_augmented.txt
# aug_data/labels/train/preset_2_Japan_012867_augmented.txt
# aug_data/labels/train/preset_2_Japan_012868_augmented.txt
# aug_data/labels/train/preset_2_Japan_012871_augmented.txt
# ...

# %%
# !git branch paper

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOR/yolor_csp_x_star.pt ./

# %%
# !python train.py --batch-size 4 --img 640 --data aug_data/data.yaml --cfg cfg/yolor_csp_x.cfg --weights yolor_csp_x_star.pt --device 0 --epochs 45 --cache --name rdd2020_aug_yolor_csp_x_pretrained_noaug
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=True, cfg='cfg/yolor_csp_x.cfg', data='aug_data/data.yaml', device='0', epochs=45, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020_aug_yolor_csp_x_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=4, weights='yolor_csp_x_star.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 8 threads.
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
make_tarfile('rdd2020_aug_yolor_csp_x_pretrained_noaug.tar.gz', 'runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug')

# %%
# %cp -r  rdd2020_aug_yolor_csp_x_pretrained_noaug.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/

# %% [markdown]
# Load last checkpoint

# %%
# %cp -r   /content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd2020_aug_yolor_csp_x_pretrained_noaug.tar.gz ./

# %%
# !tar -zxvf rdd2020_aug_yolor_csp_x_pretrained_noaug.tar.gz
# Out:
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646588772.b14329cea924.527.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/hyp.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels_correlogram.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/opt.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/results.txt
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch0.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch1.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch2.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/best.pt
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/best_ap.pt
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/best_ap50.pt
# ...

# %%
# !python train.py --batch-size 4 --img 640 --data aug_data/data.yaml --cfg cfg/yolor_csp_x.cfg --weights runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/last.pt --device 0 --epochs 58 --cache --name rdd2020_aug_yolor_csp_x_pretrained_noaug --exist-ok
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=True, cfg='cfg/yolor_csp_x.cfg', data='aug_data/data.yaml', device='0', epochs=58, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020_aug_yolor_csp_x_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=4, weights='runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/last.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 8 threads.
# ...

# %%
make_tarfile('rdd2020_aug_yolor_csp_x_pretrained_noaugv2.tar.gz', 'runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug')

# %%
# %cp -r  rdd2020_aug_yolor_csp_x_pretrained_noaugv2.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/

# %% [markdown]
# Load last checkpoint

# %%
# %cp -r   /content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd2020_aug_yolor_csp_x_pretrained_noaugv2.tar.gz ./

# %%
# !tar -zxvf rdd2020_aug_yolor_csp_x_pretrained_noaugv2.tar.gz
# Out:
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646588772.b14329cea924.527.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646776992.81529aa26a9c.514.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/hyp.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels_correlogram.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/opt.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/results.txt
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/test_batch0_labels.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch0.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch1.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch2.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/
# ...

# %%
# !python train.py --batch-size 4 --img 640 --data aug_data/data.yaml --cfg cfg/yolor_csp_x.cfg --weights runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/last.pt --device 0 --epochs 90 --cache --name rdd2020_aug_yolor_csp_x_pretrained_noaug --exist-ok
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=True, cfg='cfg/yolor_csp_x.cfg', data='aug_data/data.yaml', device='0', epochs=90, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020_aug_yolor_csp_x_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=4, weights='runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/weights/last.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 8 threads.
# ...

# %%
make_tarfile('rdd2020_aug_yolor_csp_x_pretrained_noaugv2.tar.gz', 'runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug')

# %%
make_tarfile('rdd2020_aug_yolor_csp_x_pretrained_noaugv3.tar.gz', 'runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug')

# %%
# %cp -r  rdd2020_aug_yolor_csp_x_pretrained_noaugv3.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/
