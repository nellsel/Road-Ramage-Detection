# %%
# azureml-core of version 1.0.72 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = '4fac2f62-5a4f-4708-8e06-b219c231b4bc'
resource_group = 'road-damage'
workspace_name = 'road-damage-detection'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='RDD 2020 Augmented')
dataset.download(target_path='.', overwrite=False)
# Out:
# ['/mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145992/code/Users/S00214599/RDD2020_yolo_aug_datav2.tar.gz']

# %%
# !mkdir data

# %%
# %cd data
# Out:
# [Errno 2] No such file or directory: 'data'
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145992/code/Users/S00214599/data

# %%
# !tar -zxvf '/mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145992/code/Users/S00214599/RDD2020_yolo_aug_datav2.tar.gz'
# Out:
# aug_data/
# aug_data/data.yaml
# aug_data/images/
# aug_data/images/train/
# aug_data/images/train/preset_1_Czech_000010_augmented.jpg
# aug_data/images/train/preset_1_Czech_000020_augmented.jpg
# aug_data/images/train/preset_1_Czech_000022_augmented.jpg
# aug_data/images/train/preset_1_Czech_000031_augmented.jpg
# aug_data/images/train/preset_1_Czech_000037_augmented.jpg
# aug_data/images/train/preset_1_Czech_000041_augmented.jpg
# aug_data/images/train/preset_1_Czech_000054_augmented.jpg
# aug_data/images/train/preset_1_Czech_000055_augmented.jpg
# aug_data/images/train/preset_1_Czech_000061_augmented.jpg
# aug_data/images/train/preset_1_Czech_000062_augmented.jpg
# aug_data/images/train/preset_1_Czech_000064_augmented.jpg
# aug_data/images/train/preset_1_Czech_000070_augmented.jpg
# aug_data/images/train/preset_1_Czech_000081_augmented.jpg
# aug_data/images/train/preset_1_Czech_000085_augmented.jpg
# aug_data/images/train/preset_1_Czech_000092_augmented.jpg
# ...

# %%
# %cd yolor
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145991/code/Users/S00214599/yolor

# %%
# !python train.py --batch-size 8 --img 640 --data ../data/aug_data/data.yaml --cfg models/yolor-d6.yaml --weights yolor-d6.pt  --device 0 --name rdd2020__aug_yolor_d6 --hyp hyp.scratch.1280.yaml --epochs 100 --cache
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=True, cfg='models/yolor-d6.yaml', data='../data/aug_data/data.yaml', device='0', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='./data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020__aug_yolor_d6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020__aug_yolor_d6', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolor-d6.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...
