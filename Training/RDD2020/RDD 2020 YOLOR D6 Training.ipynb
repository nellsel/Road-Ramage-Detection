# %%
# azureml-core of version 1.0.72 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = '4fac2f62-5a4f-4708-8e06-b219c231b4bc'
resource_group = 'road-damage'
workspace_name = 'road-damage-detection'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='RDD 2020')
dataset.download(target_path='.', overwrite=False)
# Out:
# ['/mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145991/code/Users/S00214599/RDD2020_yolo_data.tar.gz']

# %%
# !tar -zxvf /mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145991/code/Users/S00214599/RDD2020_yolo_data.tar.gz
# Out:
# content/data/
# content/data/data.yaml
# content/data/images/
# content/data/images/train/
# content/data/images/train/Czech_000010.jpg
# content/data/images/train/Czech_000020.jpg
# content/data/images/train/Czech_000022.jpg
# content/data/images/train/Czech_000031.jpg
# content/data/images/train/Czech_000037.jpg
# content/data/images/train/Czech_000041.jpg
# content/data/images/train/Czech_000054.jpg
# content/data/images/train/Czech_000055.jpg
# content/data/images/train/Czech_000061.jpg
# content/data/images/train/Czech_000062.jpg
# content/data/images/train/Czech_000064.jpg
# content/data/images/train/Czech_000070.jpg
# content/data/images/train/Czech_000081.jpg
# content/data/images/train/Czech_000085.jpg
# content/data/images/train/Czech_000092.jpg
# content/data/images/train/Czech_000095.jpg
# content/data/images/train/Czech_000098.jpg
# content/data/images/train/Czech_000100.jpg
# content/data/images/train/Czech_000103.jpg
# content/data/images/train/Czech_000108.jpg
# ...

# %%
# %cd yolor
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145991/code/Users/S00214599/yolor

# %%
# %pip install -qr requirements.txt  # install
# Out:
# ERROR: pycaret 2.3.6 has requirement lightgbm>=2.3.1, but you'll have lightgbm 2.3.0 which is incompatible.
# ERROR: pycaret 2.3.6 has requirement pyyaml<6.0.0, but you'll have pyyaml 6.0 which is incompatible.
# ERROR: pycaret 2.3.6 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.22.2.post1 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement joblib~=1.0.1, but you'll have joblib 0.14.1 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement matplotlib<=3.2.1,>=3.0.2, but you'll have matplotlib 3.3.4 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git checkout paper
# Out:
# Updating files: 100% (46/46), done.
# branch 'paper' set up to track 'origin/paper'.
# Switched to a new branch 'paper'

# %%
# !python train.py --batch-size 8 --img 640 --data ../content/data/data.yaml --cfg models/yolor-d6.yaml --weights yolor-d6.pt  --device 0 --name rdd2020__noaug_yolor_d6 --hyp hyp.scratch.1280.yaml --epochs 100 --cache
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=True, cfg='models/yolor-d6.yaml', data='../content/data/data.yaml', device='0', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='./data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020__noaug_yolor_d6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020__noaug_yolor_d62', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolor-d6.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...
