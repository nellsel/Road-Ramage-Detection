# %%
# %cd yolor
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/s002145992/code/Users/S00214599/yolor

# %%
# %pip install -qr requirements.txt  # install
# Out:
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)",)': /packages/80/2a/58f8078744e0408619c63148f7a2e8e48cf007e4146b74d4bb67c56d161b/torch-1.7.0-cp36-cp36m-manylinux1_x86_64.whl
# ERROR: pycaret 2.3.6 has requirement lightgbm>=2.3.1, but you'll have lightgbm 2.3.0 which is incompatible.
# ERROR: pycaret 2.3.6 has requirement pyyaml<6.0.0, but you'll have pyyaml 6.0 which is incompatible.
# ERROR: pycaret 2.3.6 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.22.2.post1 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement joblib~=1.0.1, but you'll have joblib 0.14.1 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement matplotlib<=3.2.1,>=3.0.2, but you'll have matplotlib 3.3.4 which is incompatible.
# ...

# %%
# !git stash
# Out:
# Saved working directory and index state WIP on paper: be7da6e Update README.md

# %%
# !git checkout main
# Out:
# Updating files: 100% (46/46), done.
# Switched to branch 'main'
# Your branch is behind 'origin/main' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)

# %%
# !python train.py --batch-size 4 --img 640 --data ../content/data/data.yaml --cfg cfg/yolor_w6.cfg --weights yolor_w6.pt --device 0 --epochs 100 --cache --name rdd2020_yolor_pretrained_noaug
# Out:
# Your branch is behind 'origin/main' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
#
# Using torch 1.7.0 CUDA:0 (Tesla V100-PCIE-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=4, bucket='', cache_images=True, cfg='cfg/yolor_w6.cfg', data='../content/data/data.yaml', device='0', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='rdd2020_yolor_pretrained_noaug', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/rdd2020_yolor_pretrained_noaug', single_cls=False, sync_bn=False, total_batch_size=4, weights='yolor_w6.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...
