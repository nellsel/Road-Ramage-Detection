# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#clone YOLOv5 and 
# !git clone https://github.com/nellsel/yolov5.git  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11467, done.
# remote: Counting objects: 100% (11467/11467), done.
# remote: Compressing objects: 100% (3136/3136), done.
# remote: Total 11467 (delta 8344), reused 11441 (delta 8318), pack-reused 0
# Receiving objects: 100% (11467/11467), 5.83 MiB | 24.55 MiB/s, done.
# Resolving deltas: 100% (8344/8344), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 17.6 MB/s
#      |████████████████████████████████| 67 kB 4.7 MB/s
#      |████████████████████████████████| 1.1 MB 40.5 MB/s
#      |████████████████████████████████| 178 kB 32.2 MB/s
#      |████████████████████████████████| 138 kB 28.8 MB/s
#      |████████████████████████████████| 145 kB 53.0 MB/s
#      |████████████████████████████████| 63 kB 1.4 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/Data/ireland_test_set_yolov2.zip ./

# %%
# !unzip ireland_test_set_yolov2.zip
# Out:
# Archive:  ireland_test_set_yolov2.zip
#    creating: ireland_test_set/
#   inflating: ireland_test_set/data.yaml
#    creating: ireland_test_set/.ipynb_checkpoints/
#   inflating: ireland_test_set/obj.names
#    creating: ireland_test_set/test/
#    creating: ireland_test_set/test/images/
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03841_jpg.rf.7918ab8291e3cadb74dd991e689b94dc.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene07201_jpg.rf.2d7179355fe270f8e99a407084d58d5c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03821_jpg.rf.c578596d2e12c54f214f4939265ebe5d.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene08711_jpg.rf.4ef3c55b9e2814b27acc38b24c9ecfa5.jpg
#   inflating: ireland_test_set/test/images/MaynoothVideo11_scene02671_jpg.rf.7ec09a213f2eba0820d5d1a7a13cda9c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene27901_jpg.rf.d0c52356797391bb2eef7823f449feba.jpg
# ...

# %%
# !ls -lh /content/yolov5/ireland_test_set/test/images | wc -l
# Out:
# 161

# %%
# %cd /
# Out:
# /

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOv5/Weights/NoAug/road_surfaces_yolov5_noaug.tar.gz' './'

# %%
# !tar -xvf  'road_surfaces_yolov5_noaug.tar.gz'
# Out:
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/.ipynb_checkpoints/
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/.ipynb_checkpoints/results-checkpoint.csv
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/F1_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/PR_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/P_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/R_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/confusion_matrix.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/events.out.tfevents.1643845130.ny8abkf6ud.1605.0
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/hyp.yaml
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels.jpg
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels_correlogram.jpg
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/opt.yaml
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/results.csv
# ...

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !mkdir runs

# %%
# !mv -v notebooks/yolov5/runs/* /content/yolov5/runs
# Out:
# renamed 'notebooks/yolov5/runs/train' -> '/content/yolov5/runs'

# %%
# !mkdir weights

# %%
# !python val.py --weights runs/train/road-surfaces-no-aug2/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name rsd_noaug_yolo_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['runs/train/road-surfaces-no-aug2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=rsd_noaug_yolo_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels' images and labels...160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<00:00, 1314.07it/s]
# test: New cache created: /content/yolov5/ireland_test_set/test/labels.cache
# ...

# %%
# %cd /
# Out:
# /

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/Weights/NoAug/road_surfaces_yolov5_noaug.tar.gz ./

# %%
# !tar -xvf  'road_surfaces_yolov5_noaug.tar.gz'
# Out:
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/.ipynb_checkpoints/
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/.ipynb_checkpoints/results-checkpoint.csv
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/F1_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/PR_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/P_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/R_curve.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/confusion_matrix.png
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/events.out.tfevents.1643845130.ny8abkf6ud.1605.0
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/hyp.yaml
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels.jpg
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels_correlogram.jpg
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/opt.yaml
# notebooks/yolov5/runs/train/road-surfaces-no-aug2/results.csv
# ...

# %%
# !mkdir -p /content/yolov5/runs/train/rsd-noaug

# %%
# !mv -v /notebooks/yolov5/runs/train/road-surfaces-no-aug2/* /content/yolov5/runs/train/rsd-noaug
# Out:
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/confusion_matrix.png' -> '/content/yolov5/runs/train/rsd-noaug/confusion_matrix.png'
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/events.out.tfevents.1643845130.ny8abkf6ud.1605.0' -> '/content/yolov5/runs/train/rsd-noaug/events.out.tfevents.1643845130.ny8abkf6ud.1605.0'
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/F1_curve.png' -> '/content/yolov5/runs/train/rsd-noaug/F1_curve.png'
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/hyp.yaml' -> '/content/yolov5/runs/train/rsd-noaug/hyp.yaml'
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels_correlogram.jpg' -> '/content/yolov5/runs/train/rsd-noaug/labels_correlogram.jpg'
# renamed '/notebooks/yolov5/runs/train/road-surfaces-no-aug2/labels.jpg' -> '/content/yolov5/runs/train/rsd-noaug/labels.jpg'
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/rsd-noaug/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name rdd2020_noaug_yolo_best_det

# %% [markdown]
# Merged Dataset

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# %cp -r  /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/Weights/merged_data_yolov5_noaug.tar.gz ./

# %%
# !tar -xvf  'merged_data_yolov5_noaug.tar.gz'
# Out:
# runs/train/merged_data_yolov5_noaug4/
# runs/train/merged_data_yolov5_noaug4/F1_curve.png
# runs/train/merged_data_yolov5_noaug4/PR_curve.png
# runs/train/merged_data_yolov5_noaug4/P_curve.png
# runs/train/merged_data_yolov5_noaug4/R_curve.png
# runs/train/merged_data_yolov5_noaug4/confusion_matrix.png
# runs/train/merged_data_yolov5_noaug4/events.out.tfevents.1645186158.4f37bc2fafb6.1104.0
# runs/train/merged_data_yolov5_noaug4/hyp.yaml
# runs/train/merged_data_yolov5_noaug4/labels.jpg
# runs/train/merged_data_yolov5_noaug4/labels_correlogram.jpg
# runs/train/merged_data_yolov5_noaug4/opt.yaml
# runs/train/merged_data_yolov5_noaug4/results.csv
# runs/train/merged_data_yolov5_noaug4/results.png
# runs/train/merged_data_yolov5_noaug4/train_batch0.jpg
# runs/train/merged_data_yolov5_noaug4/train_batch1.jpg
# runs/train/merged_data_yolov5_noaug4/train_batch2.jpg
# runs/train/merged_data_yolov5_noaug4/val_batch0_labels.jpg
# runs/train/merged_data_yolov5_noaug4/val_batch0_pred.jpg
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name merged_noaug_yolo_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['/content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=merged_noaug_yolo_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-48-g57614e8 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels' images and labels...160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<00:00, 989.77it/s]
# test: New cache created: /content/yolov5/ireland_test_set/test/labels.cache
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.1 --iou-thres 0.5 --augment --name merged_yolo_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['/content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.1, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=merged_yolo_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.1 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-48-g57614e8 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels.cache' images and labels... 160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.25 --iou-thres 0.5 --augment --name merged_yolo_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['/content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.25, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=merged_yolo_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.25 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-48-g57614e8 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels.cache' images and labels... 160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.3 --iou-thres 0.5 --augment --name merged_yolo_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['/content/yolov5/runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.3, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=merged_yolo_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.3 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-48-g57614e8 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels.cache' images and labels... 160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/nellsel/yolov5
#    42428ff..20c4ac1  master     -> origin/master
# Updating 42428ff..20c4ac1
# Fast-forward
#  models/common.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/nellsel/yolov5
#    20c4ac1..3186e3f  master     -> origin/master
# Updating 20c4ac1..3186e3f
# Fast-forward
#  utils/plots.py | 9 ++++-----
#  1 file changed, 4 insertions(+), 5 deletions(-)

# %%
# !python detect.py --weights runs/train/merged_data_yolov5_noaug4/weights/best.pt --conf-thres 0.22 --iou-thres 0.5 --source 'ireland_test_set/test/images' --visualize-feature-map
# Out:
# detect: weights=['runs/train/merged_data_yolov5_noaug4/weights/best.pt'], source=ireland_test_set/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.22, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, visualize_feature_map=True, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-53-g3186e3f torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# models.common.SPPF 9
# runs/detect/exp3/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9/SPPF_9_feature_map_64.png
# image 1/160 /content/yolov5/ireland_test_set/test/images/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9.jpg: 384x640 Done. (4.400s)
# models.common.SPPF 9
# ...

# %%
# !python detect.py --weights runs/train/merged_data_yolov5_noaug4/weights/best.pt --conf-thres 0.22 --iou-thres 0.5 --source 'ireland_test_set/test/images' --visualize
# Out:
# ...
# detect: weights=['runs/train/merged_data_yolov5_noaug4/weights/best.pt'], source=ireland_test_set/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.22, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=True, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-48-g57614e8 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# Saving runs/detect/exp/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9/stage0_Conv_features.png... (32/80)
# Saving runs/detect/exp/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9/stage1_Conv_features.png... (32/160)
# ...

# %%
# !python detect.py --weights runs/train/merged_data_yolov5_noaug4/weights/best.pt --conf-thres 0.22 --iou-thres 0.5 --source 'ireland_test_set/test/images' --name merged_yolor_d6_det_viz
# Out:
# detect: weights=['runs/train/merged_data_yolov5_noaug4/weights/best.pt'], source=ireland_test_set/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.22, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=merged_yolor_d6_det_viz, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-49-ge71e3dc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# models.common.Conv
# models.common.Conv
# models.common.C3
# models.common.Conv
# models.common.C3
# models.common.Conv
# models.common.C3
# models.common.Conv
# models.common.C3
# models.common.SPPF
# models.common.Conv
# torch.nn.modules.upsampling.Upsample
# models.common.Concat
# models.common.C3
# models.common.Conv
# torch.nn.modules.upsampling.Upsample
# models.common.Concat
# models.common.C3
# ...

# %%
# !python detect.py --weights runs/train/merged_data_yolov5_noaug4/weights/best.pt --conf-thres 0.22 --iou-thres 0.5 --source 'ireland_test_set/test/images' --name merged_yolor_d6_det_viz --exist-ok
# Out:
# detect: weights=['runs/train/merged_data_yolov5_noaug4/weights/best.pt'], source=ireland_test_set/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.22, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=merged_yolor_d6_det_viz, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-49-ge71e3dc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# models.common.SPPF 9
# Model Summary: 444 layers, 86193601 parameters, 0 gradients
# models.common.SPPF 9
# SPPF_9_feature_map_64.png
# image 1/160 /content/yolov5/ireland_test_set/test/images/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9.jpg: 384x640 Done. (4.746s)
# models.common.SPPF 9
# SPPF_9_feature_map_64.png
# ...

# %% [markdown]
# RDD2020

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/Weights/NoAug/RDD2020_yolov5_noaug.tar.gz ./

# %%
# !tar -xvzf RDD2020_yolov5_noaug.tar.gz
# Out:
# yolov5/runs/train/no-aug2/
# yolov5/runs/train/no-aug2/.ipynb_checkpoints/
# yolov5/runs/train/no-aug2/.ipynb_checkpoints/results-checkpoint.csv
# yolov5/runs/train/no-aug2/F1_curve.png
# yolov5/runs/train/no-aug2/PR_curve.png
# yolov5/runs/train/no-aug2/P_curve.png
# yolov5/runs/train/no-aug2/R_curve.png
# yolov5/runs/train/no-aug2/confusion_matrix.png
# yolov5/runs/train/no-aug2/events.out.tfevents.1643835050.n05ex67dtx.1429.0
# yolov5/runs/train/no-aug2/hyp.yaml
# yolov5/runs/train/no-aug2/labels.jpg
# yolov5/runs/train/no-aug2/labels_correlogram.jpg
# yolov5/runs/train/no-aug2/opt.yaml
# yolov5/runs/train/no-aug2/results.csv
# yolov5/runs/train/no-aug2/results.png
# yolov5/runs/train/no-aug2/weights/
# yolov5/runs/train/no-aug2/weights/best.pt
# yolov5/runs/train/no-aug2/weights/last.pt

# %%
# !python val.py --weights yolov5/runs/train/no-aug2/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name rdd2020_noaug_yolo_best_detv
# Out:
# val: data=ireland_test_set/data.yaml, weights=['yolov5/runs/train/no-aug2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=rdd2020_noaug_yolo_best_detv, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels.cache' images and labels... 160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
make_tarfile('yolov5_validations.tar.gz', 'runs/val')

# %%
# %cp -r yolov5_validations.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/

# %% [markdown]
# RDD 2020 Augmented

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/Weights/rdd2020_yolov5_augv4.tar.gz ./

# %%
# !tar -xvzf rdd2020_yolov5_augv4.tar.gz
# Out:
# runs/train/rdd2020_yolov5_aug/
# runs/train/rdd2020_yolov5_aug/F1_curve.png
# runs/train/rdd2020_yolov5_aug/PR_curve.png
# runs/train/rdd2020_yolov5_aug/P_curve.png
# runs/train/rdd2020_yolov5_aug/R_curve.png
# runs/train/rdd2020_yolov5_aug/confusion_matrix.png
# runs/train/rdd2020_yolov5_aug/events.out.tfevents.1646417986.80b540e1f0c0.1423.0
# runs/train/rdd2020_yolov5_aug/events.out.tfevents.1646588200.e6229e175643.524.0
# runs/train/rdd2020_yolov5_aug/events.out.tfevents.1646863202.898cd7b8ff44.496.0
# runs/train/rdd2020_yolov5_aug/events.out.tfevents.1646945791.4866259c0593.503.0
# runs/train/rdd2020_yolov5_aug/hyp.yaml
# runs/train/rdd2020_yolov5_aug/labels.jpg
# runs/train/rdd2020_yolov5_aug/labels_correlogram.jpg
# runs/train/rdd2020_yolov5_aug/opt.yaml
# runs/train/rdd2020_yolov5_aug/results.csv
# runs/train/rdd2020_yolov5_aug/results.png
# runs/train/rdd2020_yolov5_aug/train_batch0.jpg
# runs/train/rdd2020_yolov5_aug/train_batch1.jpg
# ...

# %%
# !python val.py --weights runs/train/rdd2020_yolov5_aug/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name rdd2020_aug_yolo_best_detv
# Out:
# ...
# val: data=ireland_test_set/data.yaml, weights=['runs/train/rdd2020_yolov5_aug/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=rdd2020_aug_yolo_best_detv, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-35-g932dc78 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# test: Scanning '/content/yolov5/ireland_test_set/test/labels' images and labels...160 found, 0 missing, 10 empty, 0 corrupt: 100% 160/160 [00:00<00:00, 1478.69it/s]
# test: New cache created: /content/yolov5/ireland_test_set/test/labels.cache
# ...

# %% [markdown]
# Ensemble

# %%
# !python val.py --weights runs/train/rdd2020_yolov5_aug/weights/best.pt runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name rdd2020_aug_yolo_best_detv
# Out:
# ...
# val: data=ireland_test_set/data.yaml, weights=['runs/train/rdd2020_yolov5_aug/weights/best.pt', 'runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=rdd2020_aug_yolo_best_detv, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-39-g4effd06 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# Ensemble created with ['runs/train/rdd2020_yolov5_aug/weights/best.pt', 'runs/train/merged_data_yolov5_noaug4/weights/best.pt']
#
# ...

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd2020_aug_yolorr_d6_best_overall.pt' ./

# %%
# !python val.py --weights  rdd2020_aug_yolorr_d6_best_overall.pt runs/train/merged_data_yolov5_noaug4/weights/best.pt --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name ensemble_rdd2020_aug_yolov5_yolor_D6_best_det
# Out:
# val: data=ireland_test_set/data.yaml, weights=['rdd2020_aug_yolorr_d6_best_overall.pt', 'runs/train/merged_data_yolov5_noaug4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=ensemble_rdd2020_aug_yolov5_yolor_D6_best_det, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.1-39-g4effd06 torch 1.10.0+cu111 CPU
#
# Traceback (most recent call last):
#   File "val.py", line 381, in <module>
#     main(opt)
#   File "val.py", line 354, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "val.py", line 138, in run
# ...

# %%
# %cd weights

# !mv 'last_95_448_32_aug2.pt'$'\r' last_95_448_32_aug2.pt
# !mv 'last_95_640_16.pt'$'\r' last_95_640_16.pt
# !mv 'last_100_100_640_16.pt'$'\r' last_100_100_640_16.pt
# !mv 'last_120_640_32_aug2.pt'$'\r' last_120_640_32_aug2.pt
# Out:
# /content/yolov5/yolov5/weights

# %%
# %cd ..
# Out:
# /content/yolov5/yolov5

# %%
# inference using best ensemble model for test1 dataset
# !python3 detect.py --weights weights/last_95_448_32_aug2.pt weights/last_95_640_16.pt weights/last_120_640_32_aug2.pt --img 640 --source /content/yolov5/yolov5/datasets/RDD2020/images/ireland_test --conf-thres 0.22 --iou-thres 0.5 --augment --agnostic-nms
# Out:
# detect: weights=['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt'], source=/content/yolov5/yolov5/datasets/RDD2020/images/ireland_test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.22, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=True, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Ensemble created with ['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt']
#
# ...

# %%
# !python val.py --weights weights/last_95_448_32_aug2.pt weights/last_95_640_16.pt weights/last_120_640_32_aug2.pt --data datasets/RDD2020/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5 --augment --name yolo_best_ensemble_det2
# Out:
# val: data=datasets/RDD2020/data.yaml, weights=['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt'], batch_size=32, imgsz=640, conf_thres=0.22, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=yolo_best_ensemble_det2, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.22 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Ensemble created with ['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt']
#
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
# function calling for creating tar.gz file
make_tarfile('yolo_det_best_ensem_data.tar.gz', 'runs/detect/exp8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-e0b04b9bc1f5> in <module>()
#       1 # function calling for creating tar.gz file
# ----> 2 make_tarfile('yolo_det_best_ensem_data.tar.gz', 'runs/detect/exp8')
#
# <ipython-input-25-a4eec0d0c8aa> in make_tarfile(output_filename, source_dir)
#       8   # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
#       9   with tarfile.open(output_filename, "w:gz") as tar:
# ---> 10     tar.add(source_dir)
#
# /usr/lib/python3.7/tarfile.py in add(self, name, arcname, recursive, filter)
#    1926
#    1927         # Create a TarInfo object from the file.
# -> 1928         tarinfo = self.gettarinfo(name, arcname)
#    1929
#    1930         if tarinfo is None:
#
# /usr/lib/python3.7/tarfile.py in gettarinfo(self, name, arcname, fileobj)
# ...

# %%
# %cp yolo_det_best_ensem_data.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/

# %%
# !python3 detect.py --weights weights/last_95_448_32_aug2.pt weights/last_95_640_16.pt weights/last_120_640_32_aug2.pt --img 640 --source /content/yolov5/yolov5/datasets/RDD2020/images/ireland_test --conf-thres 0.25 --iou-thres 0.5 --augment --agnostic-nms
# Out:
# detect: weights=['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt'], source=/content/yolov5/yolov5/datasets/RDD2020/images/ireland_test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.5, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=True, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Ensemble created with ['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt']
#
# ...

# %%
# !python val.py --weights weights/last_95_448_32_aug2.pt weights/last_95_640_16.pt weights/last_120_640_32_aug2.pt --data datasets/RDD2020/data.yaml --task test --conf-thres 0.25 --iou-thres 0.5 --augment --name yolo_best_ensemble_det2
# Out:
# val: data=datasets/RDD2020/data.yaml, weights=['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt'], batch_size=32, imgsz=640, conf_thres=0.25, iou_thres=0.5, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=yolo_best_ensemble_det2, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.25 >> 0.001 will produce invalid mAP values.
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Ensemble created with ['weights/last_95_448_32_aug2.pt', 'weights/last_95_640_16.pt', 'weights/last_120_640_32_aug2.pt']
#
# ...

# %%
# function calling for creating tar.gz file
make_tarfile('yolo_det_best_ensem_data.tar.gz', 'runs/detect')

# %%
# %cp yolo_det_best_ensem_data.tar.gz /content/drive/MyDrive/College/Thesis/RDD/YOLOv5/
