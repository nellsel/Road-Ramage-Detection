# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nellsel/yolor.git
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 530 (delta 17), reused 25 (delta 11), pack-reused 489
# Receiving objects: 100% (530/530), 3.46 MiB | 13.54 MiB/s, done.
# Resolving deltas: 100% (242/242), done.

# %%
# %cd yolor
# Out:
# /content/yolor

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 596 kB 4.3 MB/s
#      |████████████████████████████████| 776.7 MB 3.6 kB/s
#      |████████████████████████████████| 12.7 MB 51.2 MB/s
#      |████████████████████████████████| 1.5 MB 63.6 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/Data/ireland_test_set_yolov2.zip ./

# %%
# !unzip ireland_test_set_yolov2.zip
# Out:
# Archive:  ireland_test_set_yolov2.zip
#    creating: ireland_test_set/
#   inflating: ireland_test_set/data.yaml
#    creating: ireland_test_set/.ipynb_checkpoints/
#   inflating: ireland_test_set/obj.names
#    creating: ireland_test_set/test/
#    creating: ireland_test_set/test/images/
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03841_jpg.rf.7918ab8291e3cadb74dd991e689b94dc.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene07201_jpg.rf.2d7179355fe270f8e99a407084d58d5c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03821_jpg.rf.c578596d2e12c54f214f4939265ebe5d.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene08711_jpg.rf.4ef3c55b9e2814b27acc38b24c9ecfa5.jpg
#   inflating: ireland_test_set/test/images/MaynoothVideo11_scene02671_jpg.rf.7ec09a213f2eba0820d5d1a7a13cda9c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene27901_jpg.rf.d0c52356797391bb2eef7823f449feba.jpg
# ...

# %%
# !git pull
# Out:
# From https://github.com/nellsel/yolor
#  + ac1a120...b7332d0 main       -> origin/main  (forced update)
# Already up to date.

# %% [markdown]
# RDD 2020 AUG

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd_2020_aug_yolor_w6_pretrained_v2.tar.gz' ./

# %%
# !tar -xvzf rdd_2020_aug_yolor_w6_pretrained_v2.tar.gz
# Out:
# runs/train/rdd_2020_aug_yolor_w6_pretrained/
# runs/train/rdd_2020_aug_yolor_w6_pretrained/events.out.tfevents.1647300694.ada878639346.515.0
# runs/train/rdd_2020_aug_yolor_w6_pretrained/events.out.tfevents.1647385142.ca03a3cdc054.523.0
# runs/train/rdd_2020_aug_yolor_w6_pretrained/events.out.tfevents.1647385197.ca03a3cdc054.571.0
# runs/train/rdd_2020_aug_yolor_w6_pretrained/hyp.yaml
# runs/train/rdd_2020_aug_yolor_w6_pretrained/labels.png
# runs/train/rdd_2020_aug_yolor_w6_pretrained/labels_correlogram.png
# runs/train/rdd_2020_aug_yolor_w6_pretrained/opt.yaml
# runs/train/rdd_2020_aug_yolor_w6_pretrained/results.txt
# runs/train/rdd_2020_aug_yolor_w6_pretrained/test_batch0_labels.jpg
# runs/train/rdd_2020_aug_yolor_w6_pretrained/train_batch0.jpg
# runs/train/rdd_2020_aug_yolor_w6_pretrained/train_batch1.jpg
# runs/train/rdd_2020_aug_yolor_w6_pretrained/train_batch2.jpg
# runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/
# ...

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/best_overall.pt --data ireland_test_set/data.yaml --cfg cfg/yolor_w6.cfg --task test --conf-thres 0.22 --iou-thres 0.5  --name rdd_2020_aug_yolor_w6
# Out:
# Namespace(augment=False, batch_size=4, cfg='cfg/yolor_w6.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd_2020_aug_yolor_w6', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Model Summary: 665 layers, 79873400 parameters, 79873400 gradients, 113.473314200 GFLOPS
# Scanning images: 100% 160/160 [00:00<00:00, 443.64it/s]
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12884.74it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [01:33<00:00,  2.34s/it]
#                  all         160         319       0.426       0.291        0.38       0.188
# ...

# %% [markdown]
# Merged Dataset

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/merged_dataset_yolor_w6_pretrained_noaug_v2.tar.gz' ./

# %%
# !tar -xvzf merged_dataset_yolor_w6_pretrained_noaug_v2.tar.gz
# Out:
# runs/train/merged_dataset_yolor_pretrained_noaug/
# runs/train/merged_dataset_yolor_pretrained_noaug/events.out.tfevents.1647387227.93d1ee9bb1ef.553.0
# runs/train/merged_dataset_yolor_pretrained_noaug/events.out.tfevents.1647387275.93d1ee9bb1ef.630.0
# runs/train/merged_dataset_yolor_pretrained_noaug/hyp.yaml
# runs/train/merged_dataset_yolor_pretrained_noaug/labels.png
# runs/train/merged_dataset_yolor_pretrained_noaug/labels_correlogram.png
# runs/train/merged_dataset_yolor_pretrained_noaug/opt.yaml
# runs/train/merged_dataset_yolor_pretrained_noaug/results.txt
# runs/train/merged_dataset_yolor_pretrained_noaug/test_batch0_labels.jpg
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_ap.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_ap50.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_f.pt
# ...

# %%
# !mv -v /content/runs/train/merged_dataset_yolor_pretrained_noaug /content/yolor/runs/train/merged_dataset_yolor_pretrained_noaug
# Out:
# mv: cannot stat '/content/runs/train/merged_dataset_yolor_pretrained_noaug': No such file or directory

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt --data ireland_test_set/data.yaml --cfg cfg/yolor_w6.cfg --task test --conf-thres 0.22 --iou-thres 0.5  --name merged_dataset_noaug_yolor_w6_
# Out:
# Namespace(augment=False, batch_size=4, cfg='cfg/yolor_w6.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_noaug_yolor_w6_', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt'])
# Using torch 1.7.0 CPU
#
# Model Summary: 665 layers, 79873400 parameters, 79873400 gradients, 113.473314200 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14106.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [01:35<00:00,  2.38s/it]
#                  all         160         319       0.609        0.27       0.437       0.232
# ...

# %% [markdown]
# RDD 2020

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOR/rdd2020_aug_yolor_w6_best.pt ./

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_aug_yolor_w6_best.pt --data ireland_test_set/data.yaml --cfg cfg/yolor_w6.cfg --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_yolor_w6_best_det
# Out:
# Namespace(augment=False, batch_size=4, cfg='cfg/yolor_w6.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_yolor_w6_best_det', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_aug_yolor_w6_best.pt'])
# Using torch 1.7.0 CPU
#
# Model Summary: 665 layers, 79873400 parameters, 79873400 gradients, 113.473314200 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14021.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [01:34<00:00,  2.35s/it]
#                  all         160         319       0.452       0.319       0.391       0.188
# Speed: 581.6/0.7/582.3 ms inference/NMS/total per 640x640 image at batch-size 4
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
make_tarfile('yolor_w6_inference.tar.gz', 'runs/test')

# %%
# !cp -r 'yolor_w6_inference.tar.gz' '/content/drive/MyDrive/College/Thesis/'

# %% [markdown]
# Ensemble

# %%
# !mv runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt ./merged_dataset_yolor_w6_best.pt

# %%
# !mv runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/best_overall.pt ./rdd_2020_aug_yolor_w6_best_overall.pt

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/merged_dataset_yolor_d6_best_overall.pt' ./

# %%
# !git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/nellsel/yolor
#    3ecedd6..b2710fe  main       -> origin/main
# Updating 3ecedd6..b2710fe
# Fast-forward
#  test.py | 15 ++++++---------
#  1 file changed, 6 insertions(+), 9 deletions(-)

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/best_overall.pt --cfg cfg/yolor_w6.cfg  --data ireland_test_set/data.yaml --task test --conf-thres 0.22 --iou-thres 0.5   --name ensemble_yolor_w6_best_det --exist-ok
# Out:
# Namespace(augment=False, batch_size=4, cfg='cfg/yolor_w6.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=True, img_size=640, iou_thres=0.5, name='ensemble_yolor_w6_best_det', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt', 'runs/train/rdd_2020_aug_yolor_w6_pretrained/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Traceback (most recent call last):
#   File "test.py", line 348, in <module>
#     save_conf=opt.save_conf,
#   File "test.py", line 89, in test
#     model.append(ckpt['model'].fuse().eval())  # load FP32 model
# AttributeError: 'collections.OrderedDict' object has no attribute 'fuse'

# %%
# !pwd
# Out:
# /content/yolor

# %%
import torch
from utils.torch_utils import select_device

# %%
device = select_device('', batch_size=8)

# %%
ckpt = torch.load('runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt', map_location=device)

# %%
ckpt['model'].float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-154300741a8c> in <module>()
# ----> 1 ckpt['model'].float()
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'float'

# %%
for k, v in ckpt['model'].items():
  print(k)
# Out:
# module_list.1.Conv2d.weight
# module_list.1.BatchNorm2d.weight
# module_list.1.BatchNorm2d.bias
# module_list.1.BatchNorm2d.running_mean
# module_list.1.BatchNorm2d.running_var
# module_list.1.BatchNorm2d.num_batches_tracked
# module_list.2.Conv2d.weight
# module_list.2.BatchNorm2d.weight
# module_list.2.BatchNorm2d.bias
# module_list.2.BatchNorm2d.running_mean
# module_list.2.BatchNorm2d.running_var
# module_list.2.BatchNorm2d.num_batches_tracked
# module_list.3.Conv2d.weight
# module_list.3.BatchNorm2d.weight
# module_list.3.BatchNorm2d.bias
# module_list.3.BatchNorm2d.running_mean
# module_list.3.BatchNorm2d.running_var
# module_list.3.BatchNorm2d.num_batches_tracked
# module_list.5.Conv2d.weight
# module_list.5.BatchNorm2d.weight
# module_list.5.BatchNorm2d.bias
# module_list.5.BatchNorm2d.running_mean
# module_list.5.BatchNorm2d.running_var
# module_list.5.BatchNorm2d.num_batches_tracked
# module_list.6.Conv2d.weight
# module_list.6.BatchNorm2d.weight
# ...

# %%
ckpt = torch.load('merged_dataset_yolor_d6_best_overall.pt', map_location=device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-5cf963103528> in <module>()
# ----> 1 ckpt = torch.load('merged_dataset_yolor_d6_best_overall.pt', map_location=device)
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592                     opened_file.seek(orig_position)
#     593                     return torch.jit.load(opened_file)
# --> 594                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     595         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     596
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     851     unpickler = pickle_module.Unpickler(data_file, **pickle_load_args)
# ...
