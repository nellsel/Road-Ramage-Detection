# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nellsel/yolor.git
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 508, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 508 (delta 6), reused 12 (delta 4), pack-reused 489
# Receiving objects: 100% (508/508), 3.44 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# %cd yolor
# %pip install -qr requirements.txt  # install
# Out:
# /content/yolor
#      |████████████████████████████████| 596 kB 5.4 MB/s
#      |████████████████████████████████| 776.7 MB 4.1 kB/s
#      |████████████████████████████████| 12.7 MB 38.3 MB/s
#      |████████████████████████████████| 1.5 MB 39.6 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.

# %%
# %cd /content/yolor
# Out:
# /content/yolor

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/Data/ireland_test_set_yolov2.zip ./

# %%
# !unzip ireland_test_set_yolov2.zip
# Out:
# Archive:  ireland_test_set_yolov2.zip
#    creating: ireland_test_set/
#   inflating: ireland_test_set/data.yaml
#    creating: ireland_test_set/.ipynb_checkpoints/
#   inflating: ireland_test_set/obj.names
#    creating: ireland_test_set/test/
#    creating: ireland_test_set/test/images/
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03841_jpg.rf.7918ab8291e3cadb74dd991e689b94dc.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene07201_jpg.rf.2d7179355fe270f8e99a407084d58d5c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03821_jpg.rf.c578596d2e12c54f214f4939265ebe5d.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene08711_jpg.rf.4ef3c55b9e2814b27acc38b24c9ecfa5.jpg
#   inflating: ireland_test_set/test/images/MaynoothVideo11_scene02671_jpg.rf.7ec09a213f2eba0820d5d1a7a13cda9c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene27901_jpg.rf.d0c52356797391bb2eef7823f449feba.jpg
# ...

# %% [markdown]
# Road Surface Damages

# %%
# %cd /
# Out:
# /

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/NoAug/Road Surface Damages/road_surface_damages_yolov4_csp_x_noaug.tar.gz' ./

# %%
# !tar -xvzf road_surface_damages_yolov4_csp_x_noaug.tar.gz
# Out:
# content/yolor/runs/train/yolov4_csp_x_noaug3/
# content/yolor/runs/train/yolov4_csp_x_noaug3/events.out.tfevents.1644871675.8c7e487a7c8b.1221.0
# content/yolor/runs/train/yolov4_csp_x_noaug3/hyp.yaml
# content/yolor/runs/train/yolov4_csp_x_noaug3/labels.png
# content/yolor/runs/train/yolov4_csp_x_noaug3/labels_correlogram.png
# content/yolor/runs/train/yolov4_csp_x_noaug3/opt.yaml
# content/yolor/runs/train/yolov4_csp_x_noaug3/results.txt
# content/yolor/runs/train/yolov4_csp_x_noaug3/test_batch0_labels.jpg
# content/yolor/runs/train/yolov4_csp_x_noaug3/train_batch0.jpg
# content/yolor/runs/train/yolov4_csp_x_noaug3/train_batch1.jpg
# content/yolor/runs/train/yolov4_csp_x_noaug3/train_batch2.jpg
# content/yolor/runs/train/yolov4_csp_x_noaug3/weights/
# content/yolor/runs/train/yolov4_csp_x_noaug3/weights/best.pt
# content/yolor/runs/train/yolov4_csp_x_noaug3/weights/best_ap.pt
# content/yolor/runs/train/yolov4_csp_x_noaug3/weights/best_ap50.pt
# ...

# %%
# %cd content/yolor
# Out:
# /content/yolor

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/yolov4_csp_x_noaug3/weights/best_overall.pt --data ireland_test_set/data.yaml --cfg cfg/yolov4_csp_x.cfg --task test --conf-thres 0.22 --iou-thres 0.5 --augment  --name rsd_noaug_yolov4_best_det
# Out:
# Namespace(augment=True, batch_size=4, cfg='cfg/yolov4_csp_x.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rsd_noaug_yolov4_best_det', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/yolov4_csp_x_noaug3/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 611 layers, 99751053 parameters, 99751053 gradients, 222.430293600 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14287.30it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [21:10<00:00, 31.76s/it]
# ...

# %% [markdown]
# RDD 2020

# %%
# %cd /
# Out:
# /

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/NoAug/RDD 2020/yolov4_csp_x_noaugv22.tar.gz' ./

# %%
# !tar -xvzf yolov4_csp_x_noaugv22.tar.gz
# Out:
# content/yolor/runs/train/yolov4_csp_x_noaugv22/
# content/yolor/runs/train/yolov4_csp_x_noaugv22/events.out.tfevents.1644764407.b8360a62b9ad.755.0
# content/yolor/runs/train/yolov4_csp_x_noaugv22/hyp.yaml
# content/yolor/runs/train/yolov4_csp_x_noaugv22/labels.png
# content/yolor/runs/train/yolov4_csp_x_noaugv22/labels_correlogram.png
# content/yolor/runs/train/yolov4_csp_x_noaugv22/opt.yaml
# content/yolor/runs/train/yolov4_csp_x_noaugv22/results.txt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/test_batch0_labels.jpg
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best.pt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best_ap.pt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best_ap50.pt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best_f.pt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best_overall.pt
# content/yolor/runs/train/yolov4_csp_x_noaugv22/weights/best_r.pt
# ...

# %%
# %cd content/yolor
# Out:
# /content/yolor

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOv4/yolov4-csp.cfg ./

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/yolov4_csp_x_noaugv22/weights/best_overall.pt --data ireland_test_set/data.yaml  --cfg cfg/yolov4_csp_x.cfg --task test --conf-thres 0.22 --iou-thres 0.5 --augment  --name rdd2020_aug_yolov4_best_det
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory

# %% [markdown]
# RSD + RDD2020

# %%
# %cd /
# Out:
# /

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/merged_dataset_yolov4_csp_pretrained_noaugv2.tar.gz' ./

# %%
# !tar -xvzf merged_dataset_yolov4_csp_pretrained_noaugv2.tar.gz
# Out:
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/events.out.tfevents.1645387475.3aa4a674abb5.546.0
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/events.out.tfevents.1647530661.2f1066f3fdf6.521.0
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/events.out.tfevents.1647530688.2f1066f3fdf6.559.0
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/hyp.yaml
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/labels.png
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/labels_correlogram.png
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/opt.yaml
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/results.txt
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/test_batch0_labels.jpg
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/train_batch0.jpg
# runs/train/merged_dataset_yolov4_csp_pretrained_noaug/train_batch1.jpg
# ...

# %%
# !mv -v /runs/train/merged_dataset_yolov4_csp_pretrained_noaug /content/yolor/runs/train/
# Out:
# renamed '/runs/train/merged_dataset_yolov4_csp_pretrained_noaug' -> '/content/yolor/runs/train/merged_dataset_yolov4_csp_pretrained_noaug'

# %%
# %cd content/yolor
# Out:
# /content/yolor

# %%
# !python test.py --img 640 --batch 8 --weights runs/train/merged_dataset_yolov4_csp_pretrained_noaug/weights/best_overall.pt --data ireland_test_set/data.yaml --cfg cfg/yolov4_csp.cfg --task test --conf-thres 0.22 --iou-thres 0.5 --augment  --name merged_data_noaug_yolov4_best_det
# Out:
# Namespace(augment=True, batch_size=8, cfg='cfg/yolov4_csp.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_data_noaug_yolov4_best_det', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/merged_dataset_yolov4_csp_pretrained_noaug/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 517 layers, 52921437 parameters, 52921437 gradients, 120.636808800 GFLOPS
# Scanning images: 100% 160/160 [00:00<00:00, 310.17it/s]
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14051.56it/s]
# ...

# %% [markdown]
# RDD2020 Augmented

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOv4/rdd2020_yolov4_csp_x_augv2.tar.gz' ./

# %%
# !tar -xvzf rdd2020_yolov4_csp_x_augv2.tar.gz
# Out:
# runs/train/rdd2020_yolov4_csp_x_aug/
# runs/train/rdd2020_yolov4_csp_x_aug/events.out.tfevents.1646416778.015d676af2e3.507.0
# runs/train/rdd2020_yolov4_csp_x_aug/events.out.tfevents.1646499866.6c37b91adbe7.547.0
# runs/train/rdd2020_yolov4_csp_x_aug/hyp.yaml
# runs/train/rdd2020_yolov4_csp_x_aug/labels.png
# runs/train/rdd2020_yolov4_csp_x_aug/labels_correlogram.png
# runs/train/rdd2020_yolov4_csp_x_aug/opt.yaml
# runs/train/rdd2020_yolov4_csp_x_aug/results.txt
# runs/train/rdd2020_yolov4_csp_x_aug/test_batch0_labels.jpg
# runs/train/rdd2020_yolov4_csp_x_aug/train_batch0.jpg
# runs/train/rdd2020_yolov4_csp_x_aug/train_batch1.jpg
# runs/train/rdd2020_yolov4_csp_x_aug/train_batch2.jpg
# runs/train/rdd2020_yolov4_csp_x_aug/weights/
# runs/train/rdd2020_yolov4_csp_x_aug/weights/best.pt
# runs/train/rdd2020_yolov4_csp_x_aug/weights/best_ap.pt
# runs/train/rdd2020_yolov4_csp_x_aug/weights/best_ap50.pt
# runs/train/rdd2020_yolov4_csp_x_aug/weights/best_f.pt
# ...

# %%
# !mv -v /runs/train/rdd2020_yolov4_csp_x_aug /content/yolor/runs/train/
# Out:
# renamed '/runs/train/rdd2020_yolov4_csp_x_aug' -> '/content/yolor/runs/train/rdd2020_yolov4_csp_x_aug'

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/rdd2020_yolov4_csp_x_aug/weights/best.pt --data ireland_test_set/data.yaml --cfg cfg/yolov4_csp.cfg --task test --conf-thres 0.22 --iou-thres 0.5 --augment  --name rdd2020_aug_yolov4_best_det

# %%
# !python test.py --img 640 --batch 4 --weights runs/train/rdd2020_yolov4_csp_x_aug/weights/best.pt --data ireland_test_set/data.yaml --cfg cfg/yolov4_csp_x.cfg --task test --conf-thres 0.22 --iou-thres 0.5 --augment  --name rdd2020_aug_yolov4_best_det
# Out:
# Namespace(augment=True, batch_size=4, cfg='cfg/yolov4_csp_x.cfg', conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_yolov4_best_det', names='data/coco.names', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['runs/train/rdd2020_yolov4_csp_x_aug/weights/best.pt'])
# Using torch 1.7.0 CPU
#
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 611 layers, 99751053 parameters, 99751053 gradients, 222.430293600 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 13927.91it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [22:09<00:00, 33.23s/it]
# ...
