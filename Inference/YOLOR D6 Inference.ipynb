# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nellsel/yolor.git
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 530 (delta 17), reused 25 (delta 11), pack-reused 489
# Receiving objects: 100% (530/530), 3.47 MiB | 47.96 MiB/s, done.
# Resolving deltas: 100% (242/242), done.

# %%
# %cd yolor
# Out:
# /content/yolor

# %%
# !git checkout paper
# Out:
# Branch 'paper' set up to track remote branch 'paper' from 'origin'.
# Switched to a new branch 'paper'

# %%
# %pip install -qr requirements.txt  # install
# Out:
#      |████████████████████████████████| 596 kB 26.8 MB/s
#      |████████████████████████████████| 776.7 MB 3.8 kB/s
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/torchvision/
#      |████████████████████████████████| 12.7 MB 52.9 MB/s
#      |████████████████████████████████| 1.5 MB 54.8 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.7.0 which is incompatible.

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/Data/ireland_test_set_yolov2.zip ./

# %%
# !unzip ireland_test_set_yolov2.zip
# Out:
# Archive:  ireland_test_set_yolov2.zip
#    creating: ireland_test_set/
#   inflating: ireland_test_set/data.yaml
#    creating: ireland_test_set/.ipynb_checkpoints/
#   inflating: ireland_test_set/obj.names
#    creating: ireland_test_set/test/
#    creating: ireland_test_set/test/images/
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03841_jpg.rf.7918ab8291e3cadb74dd991e689b94dc.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene07201_jpg.rf.2d7179355fe270f8e99a407084d58d5c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene03821_jpg.rf.c578596d2e12c54f214f4939265ebe5d.jpg
#   inflating: ireland_test_set/test/images/LiffeyValleyVideo1_scene08711_jpg.rf.4ef3c55b9e2814b27acc38b24c9ecfa5.jpg
#   inflating: ireland_test_set/test/images/MaynoothVideo11_scene02671_jpg.rf.7ec09a213f2eba0820d5d1a7a13cda9c.jpg
#   inflating: ireland_test_set/test/images/BelfastVideo1_scene27901_jpg.rf.d0c52356797391bb2eef7823f449feba.jpg
# ...

# %% [markdown]
# RDD 2020

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/NoAug/rdd2020_noaug_yolor_d6_best.pt' ./

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_noaug_yolor_d6_best.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5  --name rdd_2020_aug_yolor_w6
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd_2020_aug_yolor_w6', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_noaug_yolor_d6_best.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14295.21it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:48<00:00,  4.20s/it]
#                  all         160         319        0.42       0.266       0.337       0.171
# Speed: 1044.3/0.6/1044.9 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/rdd_2020_aug_yolor_w62

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_noaug_yolor_d6_best.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.1 --iou-thres 0.5  --name rdd_2020_aug_yolor_w6
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.1, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd_2020_aug_yolor_w6', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_noaug_yolor_d6_best.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning images: 100% 160/160 [00:00<00:00, 4155.53it/s]
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 15608.16it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:25<00:00,  3.65s/it]
#                  all         160         319       0.324       0.315       0.315       0.153
# Speed: 906.5/0.5/907.0 ms inference/NMS/total per 640x640 image at batch-size 4
# ...

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_noaug_yolor_d6_best.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.05 --iou-thres 0.5  --name rdd_2020_aug_yolor_w6
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.05, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd_2020_aug_yolor_w6', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_noaug_yolor_d6_best.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14475.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:26<00:00,  3.66s/it]
#                  all         160         319       0.321       0.315       0.294       0.136
# Speed: 908.8/0.6/909.3 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/rdd_2020_aug_yolor_w62

# %% [markdown]
# Merged Dataset

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/merged_dataset_yolor_d6_best_overall.pt' ./

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5  --name merged_dataset_yolor_d6_best --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 11650.84it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:52<00:00,  4.32s/it]
#                  all         160         319       0.638       0.254        0.45       0.219
#                  D00         160         108       0.602       0.491       0.534       0.268
# ...

# %%
# !python detect.py --img 640 --weights merged_dataset_yolor_d6_best_overall.pt --source ireland_test_set/test/images --conf-thres 0.22 --iou-thres 0.5  --name merged_dataset_yolor_d6_det
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.22, device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_det', project='runs/detect', save_conf=False, save_txt=False, source='ireland_test_set/test/images', update=False, view_img=False, visualize=False, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# image 1/160 /content/yolor/ireland_test_set/test/images/BelfastVideo1_scene01881_jpg.rf.3d866356d50fceb7794150d165e10ce9.jpg: 384x640 Done. (1.031s)
# image 2/160 /content/yolor/ireland_test_set/test/images/BelfastVideo1_scene02141_jpg.rf.4d24ff3ce4e4d3224adb219337cc9c2f.jpg: 384x640 1 D00s, Done. (0.961s)
# image 3/160 /content/yolor/ireland_test_set/test/images/BelfastVideo1_scene02441_jpg.rf.580706f4699527cfce3470b1cb02990a.jpg: 384x640 1 D00s, Done. (0.910s)
# ...

# %%
# !python detect.py --img 640 --weights merged_dataset_yolor_d6_best_overall.pt --source ireland_test_set/test/images --conf-thres 0.22 --iou-thres 0.5  --name merged_dataset_yolor_d6_det --visualize
# Out:
# Streaming output truncated to the last 5000 lines.
# image 42/160 /content/yolor/ireland_test_set/test/images/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a.jpg: Saving runs/detect/merged_dataset_yolor_d6_det6/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a/stage0_ReOrg_features.png... (12/12)
# Saving runs/detect/merged_dataset_yolor_d6_det6/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a/stage1_Conv_features.png... (32/80)
# Saving runs/detect/merged_dataset_yolor_d6_det6/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a/stage2_DownC_features.png... (32/160)
# Saving runs/detect/merged_dataset_yolor_d6_det6/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a/stage3_BottleneckCSPF_features.png... (32/160)
# Saving runs/detect/merged_dataset_yolor_d6_det6/DublinVideo11_scene08561_jpg.rf.3c6c69aae2a82ba2bb76569bd97cb15a/stage4_DownC_features.png... (32/320)
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.2 --iou-thres 0.5  --name merged_dataset_yolor_d6_best
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.2, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 15747.34it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:24<00:00,  3.62s/it]
#                  all         160         319        0.62        0.26       0.445       0.217
# Speed: 900.0/0.5/900.5 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/merged_dataset_yolor_d6_best3

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.25 --iou-thres 0.5  --name merged_dataset_yolor_d6_best
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.25, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 16280.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:23<00:00,  3.59s/it]
#                  all         160         319       0.656       0.243       0.453       0.222
# Speed: 890.9/0.4/891.3 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/merged_dataset_yolor_d6_best4

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.3 --iou-thres 0.5  --name merged_dataset_yolor_d6_best --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.3, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12893.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:50<00:00,  4.26s/it]
#                  all         160         319       0.706       0.217       0.465       0.228
#                  D00         160         108       0.632       0.398       0.514       0.264
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.4 --iou-thres 0.5  --name merged_dataset_yolor_d6_best --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.4, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12781.91it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:50<00:00,  4.26s/it]
#                  all         160         319       0.529       0.165       0.352        0.17
#                  D00         160         108       0.692       0.333       0.511       0.257
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.1 --iou-thres 0.5  --name merged_dataset_yolor_d6_best
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.1, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 15763.99it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:18<00:00,  3.46s/it]
#                  all         160         319       0.479       0.342       0.414       0.172
# Speed: 860.0/0.5/860.5 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/merged_dataset_yolor_d6_best

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.15 --iou-thres 0.5  --name merged_dataset_yolor_d6_best --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.15, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14028.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:55<00:00,  4.39s/it]
#                  all         160         319       0.473       0.304        0.39       0.188
#                  D00         160         108       0.526       0.565       0.536       0.265
# ...

# %% [markdown]
# RDD Augmented 2020

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd2020_aug_yolorr_d6_best_overall.pt' ./

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_aug_yolorr_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_yolor_d6_best_det
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_aug_yolorr_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 14538.00it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:42<00:00,  4.07s/it]
#                  all         160         319       0.451       0.307       0.376       0.172
# Speed: 1011.6/0.6/1012.2 ms inference/NMS/total per 640x640 image at batch-size 4
# Results saved to runs/test/rdd2020_aug_yolor_d6_best_det2

# %% [markdown]
# Merged Dataset 418

# %%
# !cp -r /content/drive/MyDrive/College/Thesis/RDD/YOLOR/merged_data_aug_416_yolor_d6.tar.gz ./

# %%
# !tar -xvzf merged_data_aug_416_yolor_d6.tar.gz
# Out:
# runs/train/merged_data_416_yolor_d66/
# runs/train/merged_data_416_yolor_d66/events.out.tfevents.1648226299.322946cc11ab.1002.0
# runs/train/merged_data_416_yolor_d66/hyp.yaml
# runs/train/merged_data_416_yolor_d66/labels.png
# runs/train/merged_data_416_yolor_d66/labels_correlogram.png
# runs/train/merged_data_416_yolor_d66/opt.yaml
# runs/train/merged_data_416_yolor_d66/results.txt
# runs/train/merged_data_416_yolor_d66/test_batch0_labels.jpg
# runs/train/merged_data_416_yolor_d66/train_batch0.jpg
# runs/train/merged_data_416_yolor_d66/train_batch1.jpg
# runs/train/merged_data_416_yolor_d66/train_batch2.jpg
# runs/train/merged_data_416_yolor_d66/weights/
# runs/train/merged_data_416_yolor_d66/weights/best.pt
# runs/train/merged_data_416_yolor_d66/weights/best_ap.pt
# runs/train/merged_data_416_yolor_d66/weights/best_ap50.pt
# runs/train/merged_data_416_yolor_d66/weights/best_f.pt
# runs/train/merged_data_416_yolor_d66/weights/best_overall.pt
# ...

# %%
# !python test.py --img 640 --batch 8 --weights runs/train/merged_data_416_yolor_d66/weights/best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.2 --iou-thres 0.5  --name merged_416_yolor_d6_best --verbose
# Out:
# Namespace(augment=False, batch_size=8, conf_thres=0.2, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='merged_416_yolor_d6_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['runs/train/merged_data_416_yolor_d66/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12771.21it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 20/20 [02:52<00:00,  8.62s/it]
#                  all         160         319       0.435       0.281       0.366       0.155
#                  D00         160         108       0.537       0.537       0.549       0.276
# ...

# %% [markdown]
# Ensemble Model

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt rdd2020_aug_yolorr_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_and_merged_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Ensemble created with ['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt']
#
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12413.77it/s]
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt rdd2020_noaug_yolor_d6_best.pt rdd2020_aug_yolorr_d6_best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_and_merged_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_noaug_yolor_d6_best.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Ensemble created with ['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_noaug_yolor_d6_best.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt']
#
# ...

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_aug_yolorr_d6_best_overall.pt runs/train/merged_data_416_yolor_d66/weights/best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_and_merged_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['rdd2020_aug_yolorr_d6_best_overall.pt', 'runs/train/merged_data_416_yolor_d66/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Ensemble created with ['rdd2020_aug_yolorr_d6_best_overall.pt', 'runs/train/merged_data_416_yolor_d66/weights/best_overall.pt']
#
# Scanning labels ireland_test_set/test/labels.cache3 (150 found, 0 missing, 10 empty, 0 duplicate, for 160 images): 160it [00:00, 12677.84it/s]
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt rdd2020_aug_yolorr_d6_best_overall.pt runs/train/merged_data_416_yolor_d66/weights/best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_and_merged_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt', 'runs/train/merged_data_416_yolor_d66/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Ensemble created with ['merged_dataset_yolor_d6_best_overall.pt', 'rdd2020_aug_yolorr_d6_best_overall.pt', 'runs/train/merged_data_416_yolor_d66/weights/best_overall.pt']
#
# ...

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_noaug_yolor_d6_best.pt  runs/train/merged_data_416_yolor_d66/weights/best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det --verbose
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='ireland_test_set/data.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.5, name='rdd2020_aug_and_merged_yolor_d6_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=True, weights=['rdd2020_noaug_yolor_d6_best.pt', 'runs/train/merged_data_416_yolor_d66/weights/best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Traceback (most recent call last):
#   File "test.py", line 313, in <module>
#     save_conf=opt.save_conf,
#   File "test.py", line 55, in test
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#   File "/content/yolor/models/experimental.py", line 139, in attempt_load
#     ckpt = torch.load(w, map_location=map_location)  # load
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 581, in load
#     with _open_file_like(f, 'rb') as opened_file:
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt runs/train/merged_data_416_yolor_d66/weights/best_overall.pt --data ireland_test_set/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_and_merged_yolor_d6_best_det

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/Aug/rdd2020_aug_yolor_csp_x_pretrained_noaugv4.tar.gz' ./

# %%
# !tar -xvzf rdd2020_aug_yolor_csp_x_pretrained_noaugv4.tar.gz
# Out:
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646588772.b14329cea924.527.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646776992.81529aa26a9c.514.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1646942062.288f99065604.573.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/events.out.tfevents.1647077570.781f75e3e76a.494.0
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/hyp.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/labels_correlogram.png
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/opt.yaml
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/results.txt
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/test_batch0_labels.jpg
# runs/train/rdd2020_aug_yolor_csp_x_pretrained_noaug/train_batch0.jpg
# ...

# %%
# !cp -r '/content/drive/MyDrive/College/Thesis/RDD/YOLOR/merged_dataset_yolor_w6_pretrained_noaug_v2.tar.gz' ./

# %%
# !tar -xvzf merged_dataset_yolor_w6_pretrained_noaug_v2.tar.gz
# Out:
# runs/train/merged_dataset_yolor_pretrained_noaug/
# runs/train/merged_dataset_yolor_pretrained_noaug/events.out.tfevents.1647387227.93d1ee9bb1ef.553.0
# runs/train/merged_dataset_yolor_pretrained_noaug/events.out.tfevents.1647387275.93d1ee9bb1ef.630.0
# runs/train/merged_dataset_yolor_pretrained_noaug/hyp.yaml
# runs/train/merged_dataset_yolor_pretrained_noaug/labels.png
# runs/train/merged_dataset_yolor_pretrained_noaug/labels_correlogram.png
# runs/train/merged_dataset_yolor_pretrained_noaug/opt.yaml
# runs/train/merged_dataset_yolor_pretrained_noaug/results.txt
# runs/train/merged_dataset_yolor_pretrained_noaug/test_batch0_labels.jpg
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_ap.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_ap50.pt
# runs/train/merged_dataset_yolor_pretrained_noaug/weights/best_f.pt
# ...

# %%
import tarfile

def make_tarfile(output_filename, source_dir):
  '''
  This function is used to create tar.gz file for a given folder.
  Input : output file name (string) and source directory (string)
  '''
  # Reference : https://stackoverflow.com/questions/2032403/how-to-create-full-compressed-tar-file-using-python
  with tarfile.open(output_filename, "w:gz") as tar:
    tar.add(source_dir)

# %%
make_tarfile('yolor_d6_inference.tar.gz', 'runs/test')

# %%
# !cp -r 'yolor_d6_inference.tar.gz' '/content/drive/MyDrive/College/Thesis/'

# %% [markdown]
# Ireland Test set with D10

# %%
# !pip install roboflow
# Out:
# ...
#      |████████████████████████████████| 67 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 178 kB 65.1 MB/s
# ...
#      |████████████████████████████████| 145 kB 68.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 59.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=31d66d20f4eed99d668e5416225d1498215f26c02fc3ff9516ec3e955d7f42e3
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.7
#     Uninstalling pyparsing-3.0.7:
#       Successfully uninstalled pyparsing-3.0.7
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xVsQlNMTya7zzrDKgg2c")
project = rf.workspace("myles-cullen").project("ireland-road-damage-test-set")
dataset = project.version(3).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Ireland-Road-Damage-Test-Set-3 in yolov5pytorch:: 100%|██████████| 326/326 [00:00<00:00, 1155.89it/s]

# %%
# %cd yolor
# Out:
# /content/yolor

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_noaug_yolor_d6_best.pt --data /content/Ireland-Road-Damage-Test-Set-3/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5  --name rdd_2020_without_D10_yolor_d6 --exist-ok
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='/content/Ireland-Road-Damage-Test-Set-3/data.yaml', device='', exist_ok=True, img_size=640, iou_thres=0.5, name='rdd_2020_without_D10_yolor_d6', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_noaug_yolor_d6_best.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning images: 100% 160/160 [00:00<00:00, 5785.40it/s]
# Scanning labels /content/Ireland-Road-Damage-Test-Set-3/test/labels.cache3 (144 found, 0 missing, 16 empty, 0 duplicate, for 160 images): 160it [00:00, 13749.00it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:49<00:00,  4.24s/it]
#                  all         160         287       0.199        0.17       0.179      0.0987
# ...

# %%
# !python test.py --img 640 --batch 4 --weights rdd2020_aug_yolorr_d6_best_overall.pt --data /content/Ireland-Road-Damage-Test-Set-3/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5   --name rdd2020_aug_yolor_d6_without_D10_best_det --exist-ok
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='/content/Ireland-Road-Damage-Test-Set-3/data.yaml', device='', exist_ok=True, img_size=640, iou_thres=0.5, name='rdd2020_aug_yolor_d6_without_D10_best_det', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['rdd2020_aug_yolorr_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels /content/Ireland-Road-Damage-Test-Set-3/test/labels.cache3 (144 found, 0 missing, 16 empty, 0 duplicate, for 160 images): 160it [00:00, 14505.95it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:46<00:00,  4.15s/it]
#                  all         160         287       0.217       0.185       0.206       0.111
# Speed: 1032.2/0.6/1032.8 ms inference/NMS/total per 640x640 image at batch-size 4
# ...

# %%
# !python test.py --img 640 --batch 4 --weights merged_dataset_yolor_d6_best_overall.pt --data /content/Ireland-Road-Damage-Test-Set-3/data.yaml  --task test --conf-thres 0.22 --iou-thres 0.5  --name merged_dataset_yolor_d6_without_D10_best --exist-ok
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.22, data='/content/Ireland-Road-Damage-Test-Set-3/data.yaml', device='', exist_ok=True, img_size=640, iou_thres=0.5, name='merged_dataset_yolor_d6_without_D10_best', project='runs/test', save_conf=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['merged_dataset_yolor_d6_best_overall.pt'])
# Using torch 1.7.0 CPU
#
# Fusing layers...
# Model Summary: 751 layers, 150979496 parameters, 0 gradients, 232.3 GFLOPS
# Scanning labels /content/Ireland-Road-Damage-Test-Set-3/test/labels.cache3 (144 found, 0 missing, 16 empty, 0 duplicate, for 160 images): 160it [00:00, 13190.15it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 40/40 [02:43<00:00,  4.08s/it]
#                  all         160         287       0.201       0.164       0.178       0.089
# Speed: 1015.1/0.6/1015.6 ms inference/NMS/total per 640x640 image at batch-size 4
# ...

# %%
import torch
from utils.torch_utils import select_device

# %%
device = select_device('', batch_size=8)

# %%
ckpt = torch.load('rdd2020_aug_yolorr_d6_best_overall.pt', map_location=device)

# %%
ckpt['model'].float()
# Out:
# Model(
#   (model): Sequential(
#     (0): ReOrg()
#     (1): Conv(
#       (conv): Conv2d(12, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU()
#     )
#     (2): DownC(
#       (cv1): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU()
#       )
#       (cv3): Conv(
#         (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
for k, v in ckpt['model'].items():
  print(k)
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-10-290eded70d8e> in <module>()
# ----> 1 for k, v in ckpt['model'].items():
#       2   print(k)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'Model' object has no attribute 'items'
